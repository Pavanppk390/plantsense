# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-065a46bc-37c8-438f-8634-dc3ba10f8a02" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-065a46bc-37c8-438f-8634-dc3ba10f8a02">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install google-genai --break-system-packages

# %%
# !python generate_logs.py
# Out:
# Enter your Gemini API key:
# Found checkpoint with 66 already-generated logs. Resuming.
# Skipping bearing_lubrication — already have 22/22 from checkpoint.
# Skipping fan — already have 20/20 from checkpoint.
# Skipping seals_other — already have 16/16 from checkpoint.
# Generating 4 more logs for subsystem: hpc (already have 8/12)...
#   -> Got 4/4 valid logs in this sub-batch
# Generating 12 more logs for subsystem: lpt_hpt (already have 0/12)...
#   -> Got 8/8 valid logs in this sub-batch
#   -> Got 4/4 valid logs in this sub-batch
# Generating 4 more logs for subsystem: edge_case (already have 0/4)...
#   -> Got 4/4 valid logs in this sub-batch
#
# Done. Total logs: 100 (14 seed + 86 generated)
# Saved to maintenance_logs_full.json
# Final subsystem distribution: {'bearing_lubrication': 24, 'hpc': 16, 'edge_case': 6, 'lpt_hpt': 16, 'fan': 21, 'seals_other': 17}

# %%
import json
import random

with open('maintenance_logs_full.json') as f:
    logs = json.load(f)

# Look at a few random GENERATED (non-seed) logs
generated_only = [log for log in logs if not log['log_id'] in [f'ML-{i:04d}' for i in range(1, 15)]]
sample = random.sample(generated_only, 5)

for log in sample:
    print(json.dumps(log, indent=2))
    print("---")
# Out:
# {
#   "log_id": "ML-0061",
#   "unit": "Engine Unit 89 (Turbofan)",
#   "date": "2026-07-30",
#   "reported_issue": "Continuous rise in No. 3 bearing cavity oil temperature and scavenging pressure, indicating progressive thermal loading and air leakage into the sump.",
#   "root_cause": "Gradual carbon face seal wear and carbon ring fracture in the forward sumps, permitting high-pressure compressor bleed air to breach the bearing cavity seal.",
#   "action_taken": "Pulled the engine from service; replaced the worn No. 3 bearing carbon seal assembly and flushed the scavenge lines.",
#   "resolution_time": "20 hrs downtime, engine cleared for service after static pressure test.",
#   "subsystem": "seals_other"
# }
# ---
# {
#   "log_id": "ML-0073",
#   "unit": "Engine Unit 03 (Turbofan)",
#   "date": "2026-03-12",
# ...

# %%
# !pip install sentence-transformers chromadb --break-system-packages
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 788.8 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 45.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 46.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 41.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.0 MB/s eta 0:00:00
# ...

# %%
# !pip install chromadb sentence-transformers langgraph langchain-google-genai google-genai streamlit --break-system-packages
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 69.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.8/72.8 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 94.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.7/561.7 kB 28.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 67.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 8.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()
# select train_FD001.txt, test_FD001.txt, RUL_FD001.txt
# Out:
#      <input type="file" id="files-e5e9206b-26e3-43f5-9646-a0477775cac6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5e9206b-26e3-43f5-9646-a0477775cac6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python embed_store.py
# Out:
# Loading logs from maintenance_logs_full.json
# Loaded 72 logs.
# Loading embedding model: all-MiniLM-L6-v2
# ...
# modules.json: 100% 349/349 [00:00<00:00, 900kB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 329kB/s]
# README.md: 100% 10.5k/10.5k [00:00<00:00, 19.4MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 164kB/s]
# config.json: 100% 612/612 [00:00<00:00, 1.68MB/s]
#
# model.safetensors: downloading bytes:  94% 85.0M/90.9M [00:01<00:00, 106MB/s, 7.25MB/s  ]
# model.safetensors: downloading bytes: 100% 85.0M/85.0M [00:01<00:00, 55.0MB/s, 8.12MB/s  ]
# model.safetensors: reconstructing file: 100% 90.9M/90.9M [00:01<00:00, 58.8MB/s, 8.80MB/s  ]
# Loading weights: 100% 103/103 [00:00<00:00, 5479.76it/s]
# tokenizer_config.json: 100% 350/350 [00:00<00:00, 1.24MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 23.2MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 59.0MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 352kB/s]
# ...

# %%
# !python retriever.py
# Out:
# ...
# Loading weights: 100% 103/103 [00:00<00:00, 3523.79it/s]
#
# Query: "vibration issue on a bearing"
# ...
# [ML-0001] (distance: 0.921, subsystem: bearing_lubrication)
# Unit: Engine Unit 47 (Turbofan)
# Issue: Elevated vibration near LP shaft bearing (station 2.5). Vibration reading 7.2 mm/s, up from baseline 3.1 mm/s over past 48 hrs of operation.
# Root cause: Lubrication degradation — oil sample showed particulate contamination above threshold, consistent with bearing wear onset.
# Action taken: Engine pulled from service, bearing inspected, lubricant flushed and replaced, oil re-sampled post-service.
# ------------------------------------------------------------
# [ML-0029] (distance: 0.932, subsystem: bearing_lubrication)
# Unit: Engine Unit 63 (Turbofan)
# Issue: Increasing trend in high-frequency acoustic emissions and vibration levels (0.12 ips to 0.38 ips) at the mid-turbine frame bearing housing (station 4.5).
# ...

# %%
# !pip install langgraph langchain-google-genai --break-system-packages
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.8/72.8 kB 1.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.7/561.7 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.9
#     Uninstalling langchain-core-1.4.9:
#       Successfully uninstalled langchain-core-1.4.9
# ...

# %%
# !python chatbot_agent.py
# Out:
# ...
# Loading weights: 100% 103/103 [00:00<00:00, 4584.81it/s]
# Enter your Gemini API key:
#
# ...
# User: Have we seen elevated bearing vibration before? What usually causes it?
# ...
# PlantSense: Yes, elevated bearing vibration is a recurring issue. Based on our maintenance logs, the root causes typically fall into three categories:
#
# 1.  **Lubrication/Contamination:** As seen in **[ML-0001]**, particulate contamination in the oil can indicate early-stage bearing wear.
# 2.  **Mechanical Misalignment:** **[ML-0029]** highlights that vibration can originate from external components, such as a misaligned scavenge pump drive gear, which introduces mechanical harmonics into the bearing housing.
# 3.  **Component Degradation:** **[ML-0088]** demonstrates that race degradation can lead to rotor imbalance, which often presents as increasing acoustic vibration and can affect downstream thermal loads.
#
# ...

# %%
# %run rebuild_state.py
# Out:
# Feature count: 14
# X_test shape: (100, 30, 14)
# Number of test engines: 100
# Rebuild complete — feature_cols, scaler, X_test, test_engine_ids all ready.

# %%
# !python embed_store.py
# Out:
# Loading logs from maintenance_logs_full.json
# Loaded 72 logs.
# Loading embedding model: all-MiniLM-L6-v2
# ...
# Loading weights: 100% 103/103 [00:00<00:00, 4803.46it/s]
# Building embedding texts...
# Computing embeddings for all logs (this may take ~10-30s)...
# Batches: 100% 3/3 [00:02<00:00,  1.04it/s]
# Setting up Chroma persistent client...
# Adding documents to Chroma collection...
#
# Done. 72 logs embedded and stored in 'chroma_db'.
# Collection name: maintenance_logs

# %%
print(feature_cols)
print(X_test.shape)
# Out:
# ['sensor_2', 'sensor_3', 'sensor_4', 'sensor_7', 'sensor_8', 'sensor_9', 'sensor_11', 'sensor_12', 'sensor_13', 'sensor_14', 'sensor_15', 'sensor_17', 'sensor_20', 'sensor_21']
# (100, 30, 14)

# %%
import importlib
import current_state
importlib.reload(current_state)

from current_state import load_models, compute_fleet_state

# %%
from current_state import load_models, compute_fleet_state
import json

lstm_model, autoencoder = load_models(
    lstm_path="plantsense_lstm_rul.pth",
    autoencoder_path="plantsense_autoencoder.keras",
    input_size=len(feature_cols),  # should be 14
)

fleet_state = compute_fleet_state(X_test, test_engine_ids, lstm_model, autoencoder)

with open("fleet_state.json", "w") as f:
    json.dump(fleet_state, f, indent=2)

print(f"Fleet state computed for {len(fleet_state)} engines.")
print("Sample entry:", list(fleet_state.items())[0])

from collections import Counter
severities = Counter(v['severity'] for v in fleet_state.values())
print("Severity distribution:", dict(severities))
# Out:
# Fleet state computed for 100 engines.
# Sample entry: ('1', {'engine_id': 1, 'predicted_rul': 135.3, 'anomaly_score': 0.1904, 'anomaly_threshold': 0.2483, 'is_anomalous': False, 'severity': 'healthy'})
# Severity distribution: {'healthy': 57, 'watch': 9, 'critical': 34}

# %%
import importlib
import current_state
importlib.reload(current_state)
# Out:
# <module 'current_state' from '/content/current_state.py'>

# %%
from current_state import compute_sensor_summary
import json

sensor_summary = compute_sensor_summary(X_test, test_engine_ids, feature_cols)

with open("sensor_summary.json", "w") as f:
    json.dump(sensor_summary, f, indent=2)

print("Sensor summary saved for", len(sensor_summary), "engines")
print("Sample:", sensor_summary["12"][:3])  # top 3 deviating sensors for engine 12
# Out:
# Sensor summary saved for 100 engines
# Sample: [{'sensor': 'sensor_8', 'avg_scaled_value': -0.756}, {'sensor': 'sensor_13', 'avg_scaled_value': -0.734}, {'sensor': 'sensor_21', 'avg_scaled_value': 0.664}]

# %%
# !python chatbot_agent.py
# Out:
# ...
# Loading weights: 100% 103/103 [00:00<00:00, 4391.41it/s]
# Enter your Gemini API key:
#
# ...
# User: What's the fleet status right now? Any engines I should worry about?
# ...
# PlantSense: The fleet currently has 100 engines: 34 are critical, 9 are on watch, and 57 are healthy.
#
# You should prioritize investigating the critical units, starting with engines 17, 18, 20, 24, 31, 32, 34, 35, 36, and 37. Would you like me to pull the sensor data for any of these specific units to identify the root cause?
#
# ...
# User: Why is engine 12 flagged? What's driving it, and have we seen anything similar before?
# ...
# PlantSense: Engine 12 is currently not flagged; it is reporting a healthy status with an anomaly score of 0.214 (below the 0.2483 threshold) and a predicted RUL of 103.2 cycles.
#
# However, the sensor data shows some early-stage deviations that warrant monitoring:
# *   **Negative deviations:** Sensor 8 (-0.756) and Sensor 13 (-0.734).
# ...

# %%
# !python shift_report_agent.py
# Out:
# ...
# Loading weights: 100% 103/103 [00:00<00:00, 4833.01it/s]
# Enter your Gemini API key:
# Generating shift report (no user prompt — this is autonomous)...
#
# ...
# SHIFT REPORT — 2026-08-10T04:23:51.756157
# ...
# **Shift Handover Report: 2026-08-10**
# Fleet status: 100 engines total (34 critical, 9 watch, 57 healthy).
#
# **Engine 34**
# *   **RUL:** 4.8 cycles
# *   **Sensors:** sensor_8 (1.49), sensor_13 (1.40), sensor_7 (-1.33)
# *   **Precedent:** ML-0036 (bearing_lubrication), ML-0063 (seals_other)
# *   **Action:** Inspect bearing lubrication and seal integrity immediately.
#
# **Engine 68**
# *   **RUL:** 5.5 cycles
# *   **Sensors:** sensor_11 (1.23), sensor_12 (-1.22), sensor_4 (1.21)
# *   **Precedent:** ML-0036 (bearing_lubrication), ML-0009 (lpt_hpt)
# *   **Action:** Prioritize LPT/HPT and lubrication system diagnostic.
#
# **Engine 31**
# *   **RUL:** 7.3 cycles
# *   **Sensors:** sensor_4 (1.35), sensor_12 (-1.31), sensor_7 (-1.29)
# ...

# %%
# !pip install streamlit --break-system-packages
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 108.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 105.3 MB/s eta 0:00:00
# ...

# %%
# !ls
# Out:
# chatbot_agent.py  maintenance_logs_checkpoint.json  sample_data
# current_state.py  maintenance_logs_full.json	    seed_logs.py
# embed_store.py	  rebuild_state.py		    shift_report_agent.py
# generate_logs.py  retriever.py			    streamlit_app.py

# %%
from current_state import compute_sensor_summary
import json

sensor_summary = compute_sensor_summary(X_test, test_engine_ids, feature_cols)

with open("sensor_summary.json", "w") as f:
    json.dump(sensor_summary, f, indent=2)

print("sensor_summary.json created for", len(sensor_summary), "engines")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1074/291557135.py in <cell line: 0>()
#       2 import json
#       3
# ----> 4 sensor_summary = compute_sensor_summary(X_test, test_engine_ids, feature_cols)
#       5
#       6 with open("sensor_summary.json", "w") as f:
#
# NameError: name 'X_test' is not defined

# %%
# !cat /content/logs.txt
# Out:
# ...
#
# 2026-08-10 14:43:08.310 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.53.88.163:8501
#
#   Stopping...

# %%
# !ps aux | grep streamlit
# Out:
# root       22459  0.2  0.0      0     0 ?        Z    14:58   0:04 [streamlit] <defunct>
# root       30010  0.0  0.0   7372  3404 ?        S    15:29   0:00 /bin/bash -c ps aux | grep streamlit
# root       30012  0.0  0.0   6480  2376 ?        S    15:29   0:00 grep streamlit

# %%
# !cat /content/logs.txt
# Out:
# ...
#
# 2026-08-10 15:10:57.636 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.53.88.163:8501
#
# ...
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 13311.56it/s]
#   Stopping...

# %%
# !ps aux | grep cloudflared
# Out:
# root       29686  0.3  0.2 1294100 39608 ?       Sl   15:28   0:00 ./cloudflared-linux-amd64 tunnel --url http://localhost:8501
# root       30118  0.0  0.0   7372  3428 ?        S    15:30   0:00 /bin/bash -c ps aux | grep cloudflared
# root       30120  0.0  0.0   6480  2440 ?        S    15:30   0:00 grep cloudflared

# %%
# !free -h
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       1.3Gi       8.3Gi       3.0Mi       3.1Gi        11Gi
# Swap:             0B          0B          0B

# %%
# !pkill -9 -f streamlit
# !pkill -9 -f cloudflared

# %%
import time
time.sleep(3)

# %%
import subprocess

streamlit_process = subprocess.Popen(
    ["streamlit", "run", "streamlit_app.py", "--server.port", "8501"],
    stdout=open("/content/logs.txt", "w"),
    stderr=subprocess.STDOUT,
)
time.sleep(8)

# %%
# !ps aux | grep streamlit
# Out:
# root       30664 15.6  0.5 523376 69980 ?        Sl   15:32   0:02 /usr/bin/python3 /usr/local/bin/streamlit run streamlit_app.py --server.port 8501
# root       30732  0.0  0.0   7372  3452 ?        S    15:32   0:00 /bin/bash -c ps aux | grep streamlit
# root       30734  0.0  0.0   6480  2544 ?        S    15:32   0:00 grep streamlit

# %%
tunnel = subprocess.Popen(
    ["./cloudflared-linux-amd64", "tunnel", "--url", "http://localhost:8501"],
    stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True,
)
time.sleep(6)
for _ in range(30):
    line = tunnel.stdout.readline()
    print(line, end="")
    if "trycloudflare.com" in line and "https://" in line:
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1074/7815532.py in <cell line: 0>()
# ----> 1 tunnel = subprocess.Popen(
#       2     ["./cloudflared-linux-amd64", "tunnel", "--url", "http://localhost:8501"],
#       3     stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True,
#       4 )
#       5 time.sleep(6)
#
# NameError: name 'subprocess' is not defined
